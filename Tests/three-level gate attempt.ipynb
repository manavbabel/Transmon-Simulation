# %%
from qutip import *
import numpy as np
import matplotlib.pyplot as plt

# %%
(destroy(3) + create(3)).full()
# Out:
# array([[0.        +0.j, 1.        +0.j, 0.        +0.j],
#        [1.        +0.j, 0.        +0.j, 1.41421356+0.j],
#        [0.        +0.j, 1.41421356+0.j, 0.        +0.j]])

# %%
result = mesolve(jmat(1)[0], basis(3,0), np.linspace(0, 10, 1000), [], [])

# %%
n = create(3)*destroy(3)
level_ops = [basis(3,i)* basis(3,i).dag() for i in range(3)]

# %%
[plt.plot(np.linspace(0, 1, 1000), [expect(j, i) for i in result.states]) for j in level_ops]
plt.legend(["n="+str(i) for i in range(3)])
plt.axhline(0.5)
plt.axhline(0.25)
plt.show()

# %%
qutrit_ops()
jmat(1)

# %%
expand_operator(rx(np.pi/2, N=1, target=0), N=1, targets=[0], dims=[3])
